# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

'''penalty : Literal['l1','l2','elasticnet] | None = 'l2'
model = LogisticRegression(penalty = 'l1')
model = LogisticRegression(penalty = 'l2')
model = LogisticRegression(penalty = 'elasticnet')

2)solver
it is a optimazation engine which helps gradient descent to optimize the weights
solver : Literal['lbfgs' , 'liblinear' , 'newton-cg', 'newton-cholesky', 'sag','saga']

solver	         penalty	              multinomial multiclass
'lbfgs'	          'l2', None	                   yes
'liblinear'	      'l1', 'l2'	                   no
'newton-cg'	      'l2', None	                   yes
'newton-cholesky' 'l2', None	                   no
'sag'	          'l2', None	                   yes
'saga'	          'elasticnet', 'l1',  'l2', None   yes

'sag' and 'saga' are used for more number of features[high dimension] i.e sentenced based classification 

3)  max_iter :
    max_iter : int, default=100

    tol : float, default=1e-4
Tolerance for stopping criteria. i.e it stops reducing the iteration and helps the gradient descent
 to get the best weights which means it reached the best weights.

4) class_weight 
   class weight = None | 'balanced'

   C : float, default=1.0 [regularization strength]
   this parameter decides whether the model is underfit or overfit or goodfit

'''
# Out:
# 'penalities'

# %%
LogisticRegression()
# Out:
# LogisticRegression()
